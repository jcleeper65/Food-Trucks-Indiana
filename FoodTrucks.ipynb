# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from skimage import data, io

# %%
FTD_df = pd.read_csv('FoodTrucksData/Food Trucks in Indiana - Sheet1.csv')
FTD_df
# Out:
#                      Name                                            Address  \
# 0           Pastabilitiez  Medical Research/Library Building, 975 W Walnu...
# 1      Scott Diggity Dogs       901 Broad Ripple Ave, Indianapolis, IN 46220
# 2        BB&B Bread Truck            800 Lafayette St Indianapolis, IN 46202
# 3   Taqueria El Taco Loco        2705 W Washington St Indianapolis, IN 46222
# 4  Jumbo Jive Turkey Legs  910 W 10th St Peppy Grill St 13 Indianapolis, ...
# 5  Huge Impact Food Truck  5110 W 38th St, Lafayette Square, Indianapolis...
#
#    Rating                                        Website      Hour  \
# 0     4.5         https://www.facebook.com/Pastabilitiez  11am-2pm
# 1     4.0              https://www.facebook.com/Scott306  10am-9pm
# 2     4.5        https://www.booksbourbonbacon.com/bread  12pm-7pm
# 3     4.3  https://www.facebook.com/TaqueriaElTacoLoco34  5pm-11pm
# 4     3.9           https://www.jumbojiveturkeylegs.com/  11am-2pm
# ...

# %%
FTT_df = pd.read_csv('FoodTrucksData/Indiana Food Truck Tour - Sheet1 (2).csv')
FTT_df
# Out:
#                                                 Date      Time  \
# 0                      October 14th, 2023 (Saturday)  11:00 AM
# 1                                                NaN   3:30 PM
# 2                                                NaN   9:30 PM
# 3                                                NaN       NaN
# 4                                                NaN      Time
# 5                        October 15th, 2023 (Sunday)  11:00 AM
# 6                                                NaN   3:30 PM
# 7                                                NaN   8:00 PM
# 8                                                NaN       NaN
# 9  Hotel: Hampton Inn Indianapolis Downtown Acros...       NaN
#
#                      Name                                            Address  \
# 0           Pastabilitiez  Medical Research/Library Building, 975 W Walnu...
# 1  Huge Impact Food Truck  5110 W 38th St, Lafayette Square, Indianapolis...
# ...

# %%
day1 = io.imread('Day1.png')
plt.imshow(day1)
plt.show()

# %%
day2 = io.imread('Day2.png')
plt.imshow(day2)
plt.show()
